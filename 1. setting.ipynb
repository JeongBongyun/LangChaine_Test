# %% [markdown]
# ### 00. 초반 gitignore 및 README 세팅
# - .gitignore : Git 버전 관리 시스템에서 특정 파일이나 디렉토리를 추적하지 않도록 설정하는 역할의 파일
# - README : 프로젝트, 소프트웨어 또는 소스 코드 저장소에 대한 중요한 정보를 포함하는 문서 파일

# %% [markdown]
# ### Git 연동
# 1. git 설치
# ![image.png](attachment:image.png)
#
# 2. git 이름 및 email 설정
# - git config --global user.name "정봉균"
# - git config --global user.email wjdqhdrbs123@naver.com
#
# ![image-2.png](attachment:image-2.png)
#
# 3. 저장소 지정
# ![image-3.png](attachment:image-3.png)
# ![image-4.png](attachment:image-4.png)
# ![image-5.png](attachment:image-5.png)
# ![image-6.png](attachment:image-6.png)
# ![image-7.png](attachment:image-7.png)
# ![image-8.png](attachment:image-8.png)

# %%
ss
